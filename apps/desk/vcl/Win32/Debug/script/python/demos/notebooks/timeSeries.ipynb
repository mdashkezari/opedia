# %% [markdown]
# # Altimetry

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


table = 'tblAltimetry_REP'
#field = 'sla'     # sea level anomaly
#field = 'adt'     # absolute dynamic topography
#field = 'ugos'   #absolute zonal velocity
#field = 'vgos'   #absolute meridional velocity
#field = 'ugosa'   #zonal velocity anomaly
#field = 'vgosa'   #meridional velocity anomaly
field = 'ugosa'
startDate, endDate = '2016-01-19', '2016-02-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17   
arg8_name, arg8_val, extV2, extVV2 = None, None, None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, arg8_name, arg8_val, extV2, extVV2)
plot(t, y)

# %% [markdown]
# # CHL (satellite)

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


# Note: the chl dataset covers 2012 to 2016, at the momemnt (April 2018)
table = 'tblCHL_OI_REP'
field = 'chl'
startDate, endDate = '2016-01-19', '2016-02-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17  
extV, extVV, extV2, extVV2 = None, None, None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, extV, extVV, extV2, extVV2)
plot(t, y)

# %% [markdown]
# # SST (satellite)

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


table = 'tblSST_AVHRR_OI_NRT'
field = 'sst'
startDate, endDate = '2016-01-19', '2016-02-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17  
extV, extVV, extV2, extVV2 = None, None, None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, extV, extVV, extV2, extVV2)
plot(t, y)

# %% [markdown]
# # Relative Vorticity

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


table = 'tblVort_REP'
field = 'vort'
startDate, endDate = '2016-01-19', '2016-02-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17  
extV, extVV, extV2, extVV2 = None, None, None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, extV, extVV, extV2, extVV2)
plot(t, y)

# %% [markdown]
# # Wind Stress

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


table = 'tblWind_NRT'
field = 'wind_stress'
startDate, endDate = '2016-01-19', '2016-02-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17  
extV, extVV, extV2, extVV2 = None, None, None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, extV, extVV, extV2, extVV2)
plot(t, y)

# %% [markdown]
# # BioGeoChemical Model (Mercador-Pisces)

# %%
import sys
sys.path.append('../../')
import timeSeries as TS
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot(t, y):
    plt.plot(t, y, 'o')
    plt.show()


table = 'tblPisces_NRT'
#field = 'CHL'   # Chlorophyll concentration - Mean of the binned pixels
#field = 'Si'    # Mole concentration of Silicalte
#field = 'PHYC'  # Mole concentration of phytoplankton as carbon 
#field = 'PP'    # Net primary productivity of Carbon per unite volume 
#field = 'O2'    # Mole concentration of dissolved Oxygen
#field = 'PO4'   # Mole concentration of Phosphate 
#field = 'NO3'   # Mole concentration of dissolved Nitrate  
field = 'Fe'    # Mole concentration of dissolved Iron 
startDate, endDate = '2016-01-19', '2016-03-19'
lat1, lat2, lon1, lon2 = 30.57, 35.21, -163.43, -156.17 
extV, extVV, extV2, extVV2 = 'depth', '0.494024991989', None, None
t, y, y_std = TS.timeSeries(table, field, startDate, endDate, lat1, lat2, lon1, lon2, extV, extVV, extV2, extVV2)
plot(t, y)

# %% [markdown]
# Below is the exact values for the model's depth levels (m):
#
# * 0.494024991989
# * 1.54137504101
# * 2.64566898346
# * 3.81949496269
# * 5.07822418213
# * 6.44061422348
# * 7.92956018448
# * 9.5729970932
# * 11.404999733
# * 13.4671401978
# * 15.8100700378
# * 18.4955596924
# * 21.5988197327
# * 25.2114105225
# * 29.4447307587
# * 34.4341506958
# * 40.3440513611
# * 47.3736915588
# * 55.764289856
# * 65.8072662354
# * 77.8538513184
# * 92.3260726929
# * 109.729301453
# * 130.666000366
# * 155.850692749
# * 186.125595093
# * 222.475204468
# * 266.040313721
# * 318.127410889
# * 380.213012695
# * 453.937713623
# * 541.088928223
# * 643.566772461
# * 763.333129883
# * 902.339294434
# * 1062.43994141
# * 1245.29101562
# * 1452.25097656
# * 1684.28405762
# * 1941.89294434
# * 2225.07788086
# * 2533.3359375
# * 2865.70288086
# * 3220.82006836
# * 3597.03198242
# * 3992.48388672
# * 4405.22412109
# * 4833.29101562
# * 5274.78417969
# * 5727.91699219
